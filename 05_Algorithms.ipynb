# %% [markdown]
# # 第一章:アルゴリズムと計算量

# %% [markdown]
# ## 🟢A01 - The First Problem
# 🟢 **Status: 自力AC**(1分)

# %%
N = int(input())
print(N**2)
# Out:
# 10000

# %% [markdown]
# ## 🟢B01 - A+B Problem
# 🟢 **Status: 自力AC**(1分)

# %%
A, B = map(int, input().split())
print(A+B)
# Out:
# 200
